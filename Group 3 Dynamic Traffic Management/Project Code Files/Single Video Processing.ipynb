# %%
# Cell 1: Imports and confirm CUDA
import cv2
import numpy as np
import time
import pandas as pd
import torch
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort

# Confirm GPU
print("PyTorch:", torch.__version__)
print("Built with CUDA:", torch.version.cuda)
print("cuda available?", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch: 2.5.1
# Built with CUDA: 12.1
# cuda available? True
# GPU: NVIDIA GeForce GTX 1650

# %%
# Cell 2: Model and tracker setup

# 1) Load the YOLOv8x model
model = YOLO("yolov8x.pt")

# 2) Send it to GPU
model.to("cuda:0")

# 3) Initialize DeepSORT tracker
tracker = DeepSort(max_age=30, n_init=2)

# 4) Define which classes to track
target_classes = ['car', 'bus', 'truck', 'motorcycle']

# 5) Prepare storage for results
vehicle_info = {}
last_positions = {}
last_times = {}

print("Model loaded on", next(model.model.parameters()).device)
print("Tracker ready.")
# Out:
# Model loaded on cuda:0
# Tracker ready.

# %%
# Cell 3: Speed estimation helper

# Calibrate this: number of pixels that correspond to 1 meter in your video
PIXELS_PER_METER = 10  

def estimate_speed(prev_pos, curr_pos, dt):
    """
    Estimate speed (km/h) given previous and current positions (x, y) and time delta (seconds).
    """
    if prev_pos is None or curr_pos is None or dt <= 0:
        return 0.0
    dx = curr_pos[0] - prev_pos[0]
    dy = curr_pos[1] - prev_pos[1]
    dist_pixels = (dx**2 + dy**2)**0.5
    dist_m = dist_pixels / PIXELS_PER_METER
    speed_m_s = dist_m / dt
    speed_kmh = speed_m_s * 3.6
    return round(speed_kmh, 2)

print("Speed helper ready. PIXELS_PER_METER =", PIXELS_PER_METER)
# Out:
# Speed helper ready. PIXELS_PER_METER = 10

# %%
# Cell 4: Video I/O setup

video_path = "traffic_video5.mp4"  # change if needed
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    raise RuntimeError(f"Failed to open {video_path}")

# Original dimensions & FPS
orig_width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
orig_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps         = cap.get(cv2.CAP_PROP_FPS) or 30.0

# Downscale for faster inference
proc_width  = orig_width // 2
proc_height = orig_height // 2

# Output writer at original size
output_path = "output_video5.mp4"
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (orig_width, orig_height))

print(f"Video opened: {orig_width}×{orig_height} @ {fps:.1f}FPS")
print(f"Processing resolution: {proc_width}×{proc_height}")
print("Output will be saved to", output_path)
# Out:
# Video opened: 1280×720 @ 28.9FPS
# Processing resolution: 640×360
# Output will be saved to output_video5.mp4

# %%
# Cell 5: process_frame with exact YOLO boxes only
def process_frame(frame, tracker, t):
    # 1) Run YOLO on full-res frame
    results = model(frame, conf=0.3, iou=0.5)

    # 2) Collect raw YOLO detections
    dets = []  # each = ((x1,y1,x2,y2), confidence, class_name)
    for r in results:
        for b in r.boxes:
            x1, y1, x2, y2 = map(int, b.xyxy[0].cpu().numpy())
            conf           = float(b.conf[0].cpu().numpy())
            name           = r.names[int(b.cls[0].cpu().numpy())]
            if name in target_classes:
                dets.append(((x1, y1, x2, y2), conf, name))

    # 3) Update DeepSORT with those detections
    tracks = tracker.update_tracks(dets, frame=frame)

    # 4) Draw only the matched YOLO box for each track
    for tr in tracks:
        if not tr.is_confirmed():
            continue
        tid = tr.track_id

        # find the YOLO det that spawned this track
        matched_box = None
        for (box, conf, name) in dets:
            # compare YOLO-box top-left to track.to_ltrb() top-left
            tx, ty, _, _ = map(int, tr.to_ltrb())
            if abs(box[0] - tx) < 20 and abs(box[1] - ty) < 20:
                matched_box = (box, name)
                break

        if not matched_box:
            continue  # skip any tracks without a fresh detection

        (x1, y1, x2, y2), label = matched_box

        # speed calc
        center       = ((x1+x2)//2, (y1+y2)//2)
        prev_p       = last_positions.get(tid)
        prev_t       = last_times.get(tid)
        spd          = estimate_speed(prev_p, center, t-prev_t) if prev_t else 0.0
        last_positions[tid] = center
        last_times[tid]     = t

        # draw the exact YOLO box
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 2)
        cv2.putText(
            frame,
            f"ID {tid} {label} {spd:.1f}km/h",
            (x1, y1-10),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.6,
            (0,255,0),
            2
        )

        # store for summary
        vehicle_info.setdefault(tid, {"label": label, "speeds": []})
        vehicle_info[tid]["speeds"].append(spd)

    # 5) Overlay count & avg speed
    total = len(vehicle_info)
    all_s = [s for info in vehicle_info.values() for s in info["speeds"]]
    avg   = round(sum(all_s)/len(all_s),1) if all_s else 0.0
    txt   = f"Count: {total}   Avg: {avg} km/h"
    cv2.rectangle(frame, (0,0), (300,30), (0,0,0), -1)
    cv2.putText(frame, txt, (10,20),
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2, cv2.LINE_AA)

    return frame

print("process_frame updated — drawing only YOLO boxes.")
# Out:
# process_frame updated — drawing only YOLO boxes.

# %%
# Cell 6: Video processing loop

frame_count    = 0
skip_interval  = 2   # process every 2nd frame to lower load
start_time     = time.time()

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame_count += 1
    current_time = time.time() - start_time

    # Skip some frames if desired
    if frame_count % skip_interval != 0:
        out.write(frame)
        continue

    # Process and write
    processed = process_frame(frame, tracker, current_time)
    out.write(processed)

    # Optional display
    cv2.imshow("Traffic Detection", processed)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# Cleanup
cap.release()
out.release()
cv2.destroyAllWindows()
torch.cuda.empty_cache()

print("✅ Video processing complete. Saved to:", output_path)
# Out:
# 0: 384x640 8 persons, 12 cars, 5 motorcycles, 1 bus, 9 trucks, 105.8ms
# Speed: 4.3ms preprocess, 105.8ms inference, 165.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 13 cars, 4 motorcycles, 1 bus, 11 trucks, 100.6ms
# Speed: 3.0ms preprocess, 100.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 11 cars, 5 motorcycles, 1 bus, 7 trucks, 96.7ms
# Speed: 2.8ms preprocess, 96.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 12 cars, 5 motorcycles, 8 trucks, 94.2ms
# Speed: 2.0ms preprocess, 94.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 12 cars, 5 motorcycles, 8 trucks, 94.3ms
# Speed: 2.7ms preprocess, 94.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 15 cars, 5 motorcycles, 1 bus, 7 trucks, 94.0ms
# Speed: 2.0ms preprocess, 94.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 14 cars, 5 motorcycles, 7 trucks, 97.0ms
# Speed: 2.4ms preprocess, 97.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 14 cars, 4 motorcycles, 7 trucks, 94.0ms
# Speed: 2.2ms preprocess, 94.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 12 cars, 5 motorcycles, 7 trucks, 135.6ms
# Speed: 1.8ms preprocess, 135.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 12 cars, 5 motorcycles, 9 trucks, 1 traffic light, 138.1ms
# Speed: 2.1ms preprocess, 138.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 13 cars, 4 motorcycles, 7 trucks, 133.3ms
# Speed: 2.6ms preprocess, 133.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 10 cars, 5 motorcycles, 1 bus, 7 trucks, 276.9ms
# Speed: 2.1ms preprocess, 276.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 10 cars, 3 motorcycles, 8 trucks, 293.7ms
# Speed: 2.9ms preprocess, 293.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 11 cars, 4 motorcycles, 11 trucks, 498.3ms
# Speed: 3.3ms preprocess, 498.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 13 cars, 4 motorcycles, 9 trucks, 454.6ms
# Speed: 3.8ms preprocess, 454.6ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 12 cars, 3 motorcycles, 1 bus, 8 trucks, 500.1ms
# Speed: 3.7ms preprocess, 500.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 9 cars, 4 motorcycles, 1 bus, 8 trucks, 362.6ms
# Speed: 4.3ms preprocess, 362.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 10 cars, 2 motorcycles, 1 bus, 10 trucks, 434.7ms
# Speed: 3.9ms preprocess, 434.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 11 cars, 1 motorcycle, 1 bus, 9 trucks, 95.9ms
# Speed: 4.2ms preprocess, 95.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 11 cars, 1 motorcycle, 1 bus, 9 trucks, 93.9ms
# Speed: 3.5ms preprocess, 93.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 13 cars, 2 motorcycles, 1 bus, 10 trucks, 98.9ms
# Speed: 2.5ms preprocess, 98.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 10 cars, 2 motorcycles, 1 bus, 9 trucks, 95.6ms
# Speed: 2.3ms preprocess, 95.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 12 cars, 3 motorcycles, 9 trucks, 84.8ms
# Speed: 1.7ms preprocess, 84.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 13 cars, 3 motorcycles, 8 trucks, 97.2ms
# Speed: 2.7ms preprocess, 97.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 13 cars, 2 motorcycles, 2 buss, 9 trucks, 1 traffic light, 143.2ms
# Speed: 2.8ms preprocess, 143.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 14 cars, 3 motorcycles, 2 buss, 6 trucks, 139.2ms
# Speed: 2.3ms preprocess, 139.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 13 cars, 3 motorcycles, 1 bus, 7 trucks, 144.0ms
# Speed: 2.5ms preprocess, 144.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 15 cars, 3 motorcycles, 1 bus, 6 trucks, 292.7ms
# Speed: 2.6ms preprocess, 292.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 14 cars, 1 motorcycle, 8 trucks, 293.0ms
# Speed: 2.8ms preprocess, 293.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 14 cars, 3 motorcycles, 2 buss, 8 trucks, 494.8ms
# Speed: 3.6ms preprocess, 494.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 13 cars, 2 motorcycles, 9 trucks, 516.5ms
# Speed: 3.8ms preprocess, 516.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 15 cars, 2 motorcycles, 7 trucks, 505.9ms
# Speed: 3.7ms preprocess, 505.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 17 cars, 2 motorcycles, 1 bus, 7 trucks, 464.2ms
# Speed: 3.1ms preprocess, 464.2ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 14 cars, 1 motorcycle, 1 bus, 6 trucks, 175.2ms
# Speed: 3.3ms preprocess, 175.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 11 cars, 1 motorcycle, 1 bus, 9 trucks, 94.0ms
# Speed: 2.1ms preprocess, 94.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 15 cars, 2 motorcycles, 6 trucks, 97.2ms
# Speed: 5.7ms preprocess, 97.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 13 cars, 3 motorcycles, 1 bus, 8 trucks, 99.1ms
# Speed: 1.9ms preprocess, 99.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 11 cars, 2 motorcycles, 10 trucks, 98.6ms
# Speed: 2.4ms preprocess, 98.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 11 cars, 2 motorcycles, 10 trucks, 99.0ms
# Speed: 2.4ms preprocess, 99.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 10 cars, 2 motorcycles, 10 trucks, 94.9ms
# Speed: 2.9ms preprocess, 94.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 10 cars, 3 motorcycles, 10 trucks, 144.8ms
# Speed: 1.8ms preprocess, 144.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 10 cars, 4 motorcycles, 10 trucks, 137.4ms
# Speed: 2.4ms preprocess, 137.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 10 cars, 4 motorcycles, 10 trucks, 139.2ms
# Speed: 2.3ms preprocess, 139.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 13 cars, 4 motorcycles, 11 trucks, 292.7ms
# Speed: 2.9ms preprocess, 292.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 10 cars, 4 motorcycles, 9 trucks, 291.8ms
# Speed: 2.7ms preprocess, 291.8ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 9 cars, 4 motorcycles, 1 bus, 11 trucks, 509.1ms
# Speed: 2.9ms preprocess, 509.1ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 10 cars, 4 motorcycles, 1 bus, 10 trucks, 1 traffic light, 520.6ms
# Speed: 3.6ms preprocess, 520.6ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 11 cars, 4 motorcycles, 1 bus, 11 trucks, 517.4ms
# Speed: 3.3ms preprocess, 517.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 10 cars, 3 motorcycles, 1 bus, 12 trucks, 1 traffic light, 497.6ms
# Speed: 3.7ms preprocess, 497.6ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 9 cars, 4 motorcycles, 1 bus, 12 trucks, 1 traffic light, 117.3ms
# Speed: 4.0ms preprocess, 117.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 11 cars, 4 motorcycles, 1 bus, 11 trucks, 97.4ms
# Speed: 3.1ms preprocess, 97.4ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 11 cars, 5 motorcycles, 9 trucks, 96.7ms
# Speed: 2.7ms preprocess, 96.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 10 cars, 7 motorcycles, 1 bus, 9 trucks, 98.2ms
# Speed: 2.7ms preprocess, 98.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 9 cars, 7 motorcycles, 2 buss, 10 trucks, 1 traffic light, 94.6ms
# Speed: 2.2ms preprocess, 94.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 9 cars, 6 motorcycles, 2 buss, 8 trucks, 1 traffic light, 95.8ms
# Speed: 1.6ms preprocess, 95.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 10 cars, 5 motorcycles, 2 buss, 7 trucks, 1 traffic light, 107.6ms
# Speed: 2.0ms preprocess, 107.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 10 cars, 5 motorcycles, 7 trucks, 1 traffic light, 141.3ms
# Speed: 2.9ms preprocess, 141.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 8 cars, 7 motorcycles, 2 buss, 7 trucks, 1 traffic light, 135.6ms
# Speed: 1.7ms preprocess, 135.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 10 cars, 8 motorcycles, 1 bus, 7 trucks, 1 traffic light, 143.4ms
# Speed: 2.4ms preprocess, 143.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 cars, 7 motorcycles, 1 bus, 9 trucks, 1 traffic light, 293.6ms
# Speed: 2.7ms preprocess, 293.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 10 cars, 5 motorcycles, 1 bus, 7 trucks, 1 traffic light, 512.2ms
# Speed: 3.1ms preprocess, 512.2ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 10 cars, 5 motorcycles, 1 bus, 7 trucks, 1 traffic light, 516.7ms
# Speed: 3.6ms preprocess, 516.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 10 cars, 6 motorcycles, 2 buss, 7 trucks, 1 traffic light, 520.4ms
# Speed: 5.3ms preprocess, 520.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 9 cars, 9 motorcycles, 6 trucks, 1 traffic light, 514.5ms
# Speed: 3.7ms preprocess, 514.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 10 cars, 7 motorcycles, 2 buss, 6 trucks, 1 traffic light, 428.1ms
# Speed: 3.6ms preprocess, 428.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 10 cars, 6 motorcycles, 2 buss, 8 trucks, 1 traffic light, 96.9ms
# Speed: 2.7ms preprocess, 96.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 8 cars, 6 motorcycles, 2 buss, 7 trucks, 98.0ms
# Speed: 2.8ms preprocess, 98.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 10 cars, 6 motorcycles, 1 bus, 7 trucks, 99.9ms
# Speed: 2.7ms preprocess, 99.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 bicycle, 11 cars, 5 motorcycles, 1 bus, 9 trucks, 94.7ms
# Speed: 3.2ms preprocess, 94.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 13 cars, 4 motorcycles, 2 buss, 9 trucks, 97.3ms
# Speed: 2.7ms preprocess, 97.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 bicycle, 11 cars, 6 motorcycles, 1 bus, 11 trucks, 1 traffic light, 105.3ms
# Speed: 2.2ms preprocess, 105.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 11 cars, 6 motorcycles, 1 bus, 9 trucks, 1 traffic light, 147.2ms
# Speed: 2.2ms preprocess, 147.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 11 cars, 6 motorcycles, 1 bus, 9 trucks, 147.8ms
# Speed: 2.4ms preprocess, 147.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 11 cars, 7 motorcycles, 1 bus, 8 trucks, 196.5ms
# Speed: 2.3ms preprocess, 196.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 11 cars, 7 motorcycles, 1 bus, 8 trucks, 293.3ms
# Speed: 2.7ms preprocess, 293.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 10 cars, 6 motorcycles, 10 trucks, 1 traffic light, 472.2ms
# Speed: 3.2ms preprocess, 472.2ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 12 cars, 6 motorcycles, 1 bus, 8 trucks, 1 traffic light, 524.8ms
# Speed: 3.6ms preprocess, 524.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 13 cars, 6 motorcycles, 9 trucks, 1 traffic light, 520.8ms
# Speed: 3.9ms preprocess, 520.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 9 cars, 7 motorcycles, 1 bus, 11 trucks, 1 traffic light, 523.2ms
# Speed: 3.8ms preprocess, 523.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 bicycle, 9 cars, 6 motorcycles, 1 bus, 11 trucks, 1 traffic light, 102.1ms
# Speed: 4.5ms preprocess, 102.1ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 10 cars, 6 motorcycles, 8 trucks, 1 traffic light, 95.5ms
# Speed: 2.5ms preprocess, 95.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 12 cars, 6 motorcycles, 9 trucks, 1 traffic light, 99.7ms
# Speed: 2.9ms preprocess, 99.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 11 cars, 6 motorcycles, 12 trucks, 1 traffic light, 100.6ms
# Speed: 2.8ms preprocess, 100.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 9 cars, 6 motorcycles, 15 trucks, 1 traffic light, 99.8ms
# Speed: 2.2ms preprocess, 99.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 10 cars, 6 motorcycles, 1 bus, 8 trucks, 1 traffic light, 95.7ms
# Speed: 2.1ms preprocess, 95.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 12 cars, 7 motorcycles, 10 trucks, 1 traffic light, 135.7ms
# Speed: 2.7ms preprocess, 135.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 11 cars, 7 motorcycles, 2 buss, 6 trucks, 1 traffic light, 143.9ms
# Speed: 2.3ms preprocess, 143.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 11 cars, 6 motorcycles, 2 buss, 9 trucks, 1 traffic light, 141.6ms
# Speed: 2.3ms preprocess, 141.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 10 cars, 7 motorcycles, 2 buss, 8 trucks, 1 traffic light, 292.8ms
# Speed: 2.9ms preprocess, 292.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 12 cars, 6 motorcycles, 1 bus, 10 trucks, 1 traffic light, 307.4ms
# Speed: 2.5ms preprocess, 307.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 10 cars, 5 motorcycles, 9 trucks, 1 traffic light, 529.5ms
# Speed: 2.9ms preprocess, 529.5ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 13 cars, 7 motorcycles, 9 trucks, 512.6ms
# Speed: 3.7ms preprocess, 512.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 10 cars, 6 motorcycles, 11 trucks, 520.7ms
# Speed: 3.9ms preprocess, 520.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 11 cars, 6 motorcycles, 11 trucks, 504.9ms
# Speed: 3.4ms preprocess, 504.9ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 11 cars, 4 motorcycles, 10 trucks, 94.7ms
# Speed: 3.2ms preprocess, 94.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 8 cars, 4 motorcycles, 11 trucks, 95.4ms
# Speed: 2.6ms preprocess, 95.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 10 cars, 4 motorcycles, 1 bus, 12 trucks, 97.9ms
# Speed: 3.7ms preprocess, 97.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 13 cars, 4 motorcycles, 1 bus, 10 trucks, 99.6ms
# Speed: 3.3ms preprocess, 99.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 10 cars, 3 motorcycles, 1 bus, 11 trucks, 98.8ms
# Speed: 1.8ms preprocess, 98.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 10 cars, 2 motorcycles, 1 bus, 12 trucks, 109.4ms
# Speed: 2.3ms preprocess, 109.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 9 cars, 2 motorcycles, 2 buss, 10 trucks, 146.4ms
# Speed: 3.0ms preprocess, 146.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 9 cars, 2 motorcycles, 2 buss, 8 trucks, 1 traffic light, 144.0ms
# Speed: 2.2ms preprocess, 144.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 8 cars, 2 motorcycles, 1 bus, 10 trucks, 1 traffic light, 199.5ms
# Speed: 2.2ms preprocess, 199.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 9 cars, 4 motorcycles, 1 bus, 10 trucks, 1 traffic light, 292.8ms
# Speed: 3.2ms preprocess, 292.8ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 10 cars, 3 motorcycles, 1 bus, 10 trucks, 1 traffic light, 536.9ms
# Speed: 3.4ms preprocess, 536.9ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 cars, 3 motorcycles, 1 bus, 10 trucks, 1 traffic light, 506.1ms
# Speed: 3.9ms preprocess, 506.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 cars, 2 motorcycles, 3 buss, 13 trucks, 1 traffic light, 525.7ms
# Speed: 3.5ms preprocess, 525.7ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 cars, 4 motorcycles, 2 buss, 13 trucks, 514.8ms
# Speed: 3.1ms preprocess, 514.8ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 8 cars, 4 motorcycles, 1 bus, 10 trucks, 173.2ms
# Speed: 3.7ms preprocess, 173.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 9 cars, 5 motorcycles, 2 buss, 10 trucks, 100.1ms
# Speed: 2.4ms preprocess, 100.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 3 motorcycles, 11 trucks, 95.6ms
# Speed: 2.5ms preprocess, 95.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 3 motorcycles, 1 bus, 10 trucks, 95.4ms
# Speed: 2.3ms preprocess, 95.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 8 cars, 4 motorcycles, 1 bus, 8 trucks, 101.6ms
# Speed: 1.8ms preprocess, 101.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 11 cars, 5 motorcycles, 1 bus, 11 trucks, 1 traffic light, 98.8ms
# Speed: 2.1ms preprocess, 98.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 12 cars, 5 motorcycles, 2 buss, 8 trucks, 107.1ms
# Speed: 2.1ms preprocess, 107.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Video processing complete. Saved to: output_video5.mp4
